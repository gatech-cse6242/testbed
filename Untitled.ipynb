# %%
import os
import sys
import numpy as np

from scipy.misc import imread
from PIL import Image, ImageOps

def crop_images(base_dir, root_dir, cropped_dir, size):
    cropped_dir_path = os.path.join(base_dir, cropped_dir)
    if not os.path.exists(cropped_dir_path):
        os.makedirs(cropped_dir_path)
        print('Created new directory: ', cropped_dir_path)

    # Walk the directory tree (for the not-yet-cropped images).
    for subdir, dirs, files in os.walk(root_dir):
      for dir in dirs:
        old_dir = os.path.join(root_dir, dir)
        new_dir = os.path.join(cropped_dir, dir)

        # If a corresponding subfolder to hold the cropped images doesn't
        # yet exist, create one.
        if not os.path.exists(new_dir):
          os.makedirs(new_dir)

        for x, y, image_files in os.walk(old_dir):
            for image in image_files:
                image_path = os.path.join(old_dir, image)
                new_image_path = os.path.join(new_dir, image)

                try:
                    im = Image.open(image_path)
                    thumb = ImageOps.fit(im, size, Image.ANTIALIAS)
                    thumb.save(new_image_path, 'JPEG')

                except Exception as e:
                    continue

size = (256, 256)
base_dir = '/Users/mbmay/proj/'
root_dir = base_dir + 'dermis-img'
cropped_dir = base_dir + 'dermis-img-cropped'

#crop_images(base_dir, root_dir, cropped_dir, size)

# %%
def prepare_image(image_file):
    return imread(image_file)

def prepare_images():
    images = []
    data = []
    
    for subdir, dirs, files in os.walk(cropped_dir):
        for file in files:
            images.append(os.path.join(subdir, file))
    
    num_images = len(images)
    for i, image in enumerate(images):
        prepared = prepare_image(image)
        data.append(prepared)
        
        print "Added image: %s/%s done" % (i, num_images-1)
        
    return [images, data, num_images]

map_dict = {
    'acne': 0,
    'alopecia': 1,
    'basal_cell_carcinoma': 2,
    'bullous': 3,
    'dermatitis': 4,
    'eczema': 5,
    'exanthem': 6,
    'herpes': 7,
    'keratosis': 8,
    'lupus': 9,
    'melanoma': 10,
    'pigment': 11,
    'psoriasis': 12,
    'rosacea': 13,
    'squamous_cell_carcinoma': 14,
    'tinea': 15,
    'vasculitis': 16
}

# Return the prepared images
image_paths, images, num_images = prepare_images()

# Prepare the label array
labels = [map_dict[f.split('/')[5]] for f in image_paths]
# Out:
# Added image: 0/2868 done
# Added image: 1/2868 done
# Added image: 2/2868 done
# Added image: 3/2868 done
# Added image: 4/2868 done
# Added image: 5/2868 done
# Added image: 6/2868 done
# Added image: 7/2868 done
# Added image: 8/2868 done
# Added image: 9/2868 done
# Added image: 10/2868 done
# Added image: 11/2868 done
# Added image: 12/2868 done
# Added image: 13/2868 done
# Added image: 14/2868 done
# Added image: 15/2868 done
# Added image: 16/2868 done
# Added image: 17/2868 done
# Added image: 18/2868 done
# Added image: 19/2868 done
# Added image: 20/2868 done
# Added image: 21/2868 done
# Added image: 22/2868 done
# Added image: 23/2868 done
# Added image: 24/2868 done
# Added image: 25/2868 done
# Added image: 26/2868 done
# Added image: 27/2868 done
# Added image: 28/2868 done
# Added image: 29/2868 done
# Added image: 30/2868 done
# Added image: 31/2868 done
# Added image: 32/2868 done
# Added image: 33/2868 done
# Added image: 34/2868 done
# Added image: 35/2868 done
# Added image: 36/2868 done
# Added image: 37/2868 done
# Added image: 38/2868 done
# Added image: 39/2868 done
# Added image: 40/2868 done
# Added image: 41/2868 done
# Added image: 42/2868 done
# Added image: 43/2868 done
# Added image: 44/2868 done
# Added image: 45/2868 done
# Added image: 46/2868 done
# Added image: 47/2868 done
# Added image: 48/2868 done
# Added image: 49/2868 done
# Added image: 50/2868 done
# Added image: 51/2868 done
# Added image: 52/2868 done
# Added image: 53/2868 done
# Added image: 54/2868 done
# Added image: 55/2868 done
# Added image: 56/2868 done
# Added image: 57/2868 done
# Added image: 58/2868 done
# Added image: 59/2868 done
# Added image: 60/2868 done
# Added image: 61/2868 done
# Added image: 62/2868 done
# Added image: 63/2868 done
# Added image: 64/2868 done
# Added image: 65/2868 done
# Added image: 66/2868 done
# Added image: 67/2868 done
# Added image: 68/2868 done
# Added image: 69/2868 done
# Added image: 70/2868 done
# Added image: 71/2868 done
# Added image: 72/2868 done
# Added image: 73/2868 done
# Added image: 74/2868 done
# Added image: 75/2868 done
# Added image: 76/2868 done
# Added image: 77/2868 done
# Added image: 78/2868 done
# Added image: 79/2868 done
# Added image: 80/2868 done
# Added image: 81/2868 done
# Added image: 82/2868 done
# Added image: 83/2868 done
# Added image: 84/2868 done
# Added image: 85/2868 done
# Added image: 86/2868 done
# Added image: 87/2868 done
# Added image: 88/2868 done
# Added image: 89/2868 done
# Added image: 90/2868 done
# Added image: 91/2868 done
# Added image: 92/2868 done
# Added image: 93/2868 done
# Added image: 94/2868 done
# Added image: 95/2868 done
# Added image: 96/2868 done
# Added image: 97/2868 done
# Added image: 98/2868 done
# Added image: 99/2868 done
# Added image: 100/2868 done
# Added image: 101/2868 done
# Added image: 102/2868 done
# Added image: 103/2868 done
# Added image: 104/2868 done
# Added image: 105/2868 done
# Added image: 106/2868 done
# Added image: 107/2868 done
# Added image: 108/2868 done
# Added image: 109/2868 done
# Added image: 110/2868 done
# Added image: 111/2868 done
# Added image: 112/2868 done
# Added image: 113/2868 done
# Added image: 114/2868 done
# Added image: 115/2868 done
# Added image: 116/2868 done
# Added image: 117/2868 done
# Added image: 118/2868 done
# Added image: 119/2868 done
# Added image: 120/2868 done
# Added image: 121/2868 done
# Added image: 122/2868 done
# Added image: 123/2868 done
# Added image: 124/2868 done
# Added image: 125/2868 done
# Added image: 126/2868 done
# Added image: 127/2868 done
# Added image: 128/2868 done
# Added image: 129/2868 done
# Added image: 130/2868 done
# Added image: 131/2868 done
# Added image: 132/2868 done
# Added image: 133/2868 done
# Added image: 134/2868 done
# Added image: 135/2868 done
# Added image: 136/2868 done
# Added image: 137/2868 done
# Added image: 138/2868 done
# Added image: 139/2868 done
# Added image: 140/2868 done
# Added image: 141/2868 done
# Added image: 142/2868 done
# Added image: 143/2868 done
# Added image: 144/2868 done
# Added image: 145/2868 done
# Added image: 146/2868 done
# Added image: 147/2868 done
# Added image: 148/2868 done
# Added image: 149/2868 done
# Added image: 150/2868 done
# Added image: 151/2868 done
# Added image: 152/2868 done
# Added image: 153/2868 done
# Added image: 154/2868 done
# Added image: 155/2868 done
# Added image: 156/2868 done
# Added image: 157/2868 done
# Added image: 158/2868 done
# Added image: 159/2868 done
# Added image: 160/2868 done
# Added image: 161/2868 done
# Added image: 162/2868 done
# Added image: 163/2868 done
# Added image: 164/2868 done
# Added image: 165/2868 done
# Added image: 166/2868 done
# Added image: 167/2868 done
# Added image: 168/2868 done
# Added image: 169/2868 done
# Added image: 170/2868 done
# Added image: 171/2868 done
# Added image: 172/2868 done
# Added image: 173/2868 done
# Added image: 174/2868 done
# Added image: 175/2868 done
# Added image: 176/2868 done
# Added image: 177/2868 done
# Added image: 178/2868 done
# Added image: 179/2868 done
# Added image: 180/2868 done
# Added image: 181/2868 done
# Added image: 182/2868 done
# Added image: 183/2868 done
# Added image: 184/2868 done
# Added image: 185/2868 done
# Added image: 186/2868 done
# Added image: 187/2868 done
# Added image: 188/2868 done
# Added image: 189/2868 done
# Added image: 190/2868 done
# Added image: 191/2868 done
# Added image: 192/2868 done
# Added image: 193/2868 done
# Added image: 194/2868 done
# Added image: 195/2868 done
# Added image: 196/2868 done
# Added image: 197/2868 done
# Added image: 198/2868 done
# Added image: 199/2868 done
# Added image: 200/2868 done
# Added image: 201/2868 done
# Added image: 202/2868 done
# Added image: 203/2868 done
# Added image: 204/2868 done
# Added image: 205/2868 done
# Added image: 206/2868 done
# Added image: 207/2868 done
# Added image: 208/2868 done
# Added image: 209/2868 done
# Added image: 210/2868 done
# Added image: 211/2868 done
# Added image: 212/2868 done
# Added image: 213/2868 done
# Added image: 214/2868 done
# Added image: 215/2868 done
# Added image: 216/2868 done
# Added image: 217/2868 done
# Added image: 218/2868 done
# Added image: 219/2868 done
# Added image: 220/2868 done
# Added image: 221/2868 done
# Added image: 222/2868 done
# Added image: 223/2868 done
# Added image: 224/2868 done
# Added image: 225/2868 done
# Added image: 226/2868 done
# Added image: 227/2868 done
# Added image: 228/2868 done
# Added image: 229/2868 done
# Added image: 230/2868 done
# Added image: 231/2868 done
# Added image: 232/2868 done
# Added image: 233/2868 done
# Added image: 234/2868 done
# Added image: 235/2868 done
# Added image: 236/2868 done
# Added image: 237/2868 done
# Added image: 238/2868 done
# Added image: 239/2868 done
# Added image: 240/2868 done
# Added image: 241/2868 done
# Added image: 242/2868 done
# Added image: 243/2868 done
# Added image: 244/2868 done
# Added image: 245/2868 done
# Added image: 246/2868 done
# Added image: 247/2868 done
# Added image: 248/2868 done
# Added image: 249/2868 done
# Added image: 250/2868 done
# Added image: 251/2868 done
# Added image: 252/2868 done
# Added image: 253/2868 done
# Added image: 254/2868 done
# Added image: 255/2868 done
# Added image: 256/2868 done
# Added image: 257/2868 done
# Added image: 258/2868 done
# Added image: 259/2868 done
# Added image: 260/2868 done
# Added image: 261/2868 done
# Added image: 262/2868 done
# Added image: 263/2868 done
# Added image: 264/2868 done
# Added image: 265/2868 done
# Added image: 266/2868 done
# Added image: 267/2868 done
# Added image: 268/2868 done
# Added image: 269/2868 done
# Added image: 270/2868 done
# Added image: 271/2868 done
# Added image: 272/2868 done
# Added image: 273/2868 done
# Added image: 274/2868 done
# Added image: 275/2868 done
# Added image: 276/2868 done
# Added image: 277/2868 done
# Added image: 278/2868 done
# Added image: 279/2868 done
# Added image: 280/2868 done
# Added image: 281/2868 done
# Added image: 282/2868 done
# Added image: 283/2868 done
# Added image: 284/2868 done
# Added image: 285/2868 done
# Added image: 286/2868 done
# Added image: 287/2868 done
# Added image: 288/2868 done
# Added image: 289/2868 done
# Added image: 290/2868 done
# Added image: 291/2868 done
# Added image: 292/2868 done
# Added image: 293/2868 done
# Added image: 294/2868 done
# Added image: 295/2868 done
# Added image: 296/2868 done
# Added image: 297/2868 done
# Added image: 298/2868 done
# Added image: 299/2868 done
# Added image: 300/2868 done
# Added image: 301/2868 done
# Added image: 302/2868 done
# Added image: 303/2868 done
# Added image: 304/2868 done
# Added image: 305/2868 done
# Added image: 306/2868 done
# Added image: 307/2868 done
# Added image: 308/2868 done
# Added image: 309/2868 done
# Added image: 310/2868 done
# Added image: 311/2868 done
# Added image: 312/2868 done
# Added image: 313/2868 done
# Added image: 314/2868 done
# Added image: 315/2868 done
# Added image: 316/2868 done
# Added image: 317/2868 done
# Added image: 318/2868 done
# Added image: 319/2868 done
# Added image: 320/2868 done
# Added image: 321/2868 done
# Added image: 322/2868 done
# Added image: 323/2868 done
# Added image: 324/2868 done
# Added image: 325/2868 done
# Added image: 326/2868 done
# Added image: 327/2868 done
# Added image: 328/2868 done
# Added image: 329/2868 done
# Added image: 330/2868 done
# Added image: 331/2868 done
# Added image: 332/2868 done
# Added image: 333/2868 done
# Added image: 334/2868 done
# Added image: 335/2868 done
# Added image: 336/2868 done
# Added image: 337/2868 done
# Added image: 338/2868 done
# Added image: 339/2868 done
# Added image: 340/2868 done
# Added image: 341/2868 done
# Added image: 342/2868 done
# Added image: 343/2868 done
# Added image: 344/2868 done
# Added image: 345/2868 done
# Added image: 346/2868 done
# Added image: 347/2868 done
# Added image: 348/2868 done
# Added image: 349/2868 done
# Added image: 350/2868 done
# Added image: 351/2868 done
# Added image: 352/2868 done
# Added image: 353/2868 done
# Added image: 354/2868 done
# Added image: 355/2868 done
# Added image: 356/2868 done
# Added image: 357/2868 done
# Added image: 358/2868 done
# Added image: 359/2868 done
# Added image: 360/2868 done
# Added image: 361/2868 done
# Added image: 362/2868 done
# Added image: 363/2868 done
# Added image: 364/2868 done
# Added image: 365/2868 done
# Added image: 366/2868 done
# Added image: 367/2868 done
# Added image: 368/2868 done
# Added image: 369/2868 done
# Added image: 370/2868 done
# Added image: 371/2868 done
# Added image: 372/2868 done
# Added image: 373/2868 done
# Added image: 374/2868 done
# Added image: 375/2868 done
# Added image: 376/2868 done
# Added image: 377/2868 done
# Added image: 378/2868 done
# Added image: 379/2868 done
# Added image: 380/2868 done
# Added image: 381/2868 done
# Added image: 382/2868 done
# Added image: 383/2868 done
# Added image: 384/2868 done
# Added image: 385/2868 done
# Added image: 386/2868 done
# Added image: 387/2868 done
# Added image: 388/2868 done
# Added image: 389/2868 done
# Added image: 390/2868 done
# Added image: 391/2868 done
# Added image: 392/2868 done
# Added image: 393/2868 done
# Added image: 394/2868 done
# Added image: 395/2868 done
# Added image: 396/2868 done
# Added image: 397/2868 done
# Added image: 398/2868 done
# Added image: 399/2868 done
# Added image: 400/2868 done
# Added image: 401/2868 done
# Added image: 402/2868 done
# Added image: 403/2868 done
# Added image: 404/2868 done
# Added image: 405/2868 done
# Added image: 406/2868 done
# Added image: 407/2868 done
# Added image: 408/2868 done
# Added image: 409/2868 done
# Added image: 410/2868 done
# Added image: 411/2868 done
# Added image: 412/2868 done
# Added image: 413/2868 done
# Added image: 414/2868 done
# Added image: 415/2868 done
# Added image: 416/2868 done
# Added image: 417/2868 done
# Added image: 418/2868 done
# Added image: 419/2868 done
# Added image: 420/2868 done
# Added image: 421/2868 done
# Added image: 422/2868 done
# Added image: 423/2868 done
# Added image: 424/2868 done
# Added image: 425/2868 done
# Added image: 426/2868 done
# Added image: 427/2868 done
# Added image: 428/2868 done
# Added image: 429/2868 done
# Added image: 430/2868 done
# Added image: 431/2868 done
# Added image: 432/2868 done
# Added image: 433/2868 done
# Added image: 434/2868 done
# Added image: 435/2868 done
# Added image: 436/2868 done
# Added image: 437/2868 done
# Added image: 438/2868 done
# Added image: 439/2868 done
# Added image: 440/2868 done
# Added image: 441/2868 done
# Added image: 442/2868 done
# Added image: 443/2868 done
# Added image: 444/2868 done
# Added image: 445/2868 done
# Added image: 446/2868 done
# Added image: 447/2868 done
# Added image: 448/2868 done
# Added image: 449/2868 done
# Added image: 450/2868 done
# Added image: 451/2868 done
# Added image: 452/2868 done
# Added image: 453/2868 done
# Added image: 454/2868 done
# Added image: 455/2868 done
# Added image: 456/2868 done
# Added image: 457/2868 done
# Added image: 458/2868 done
# Added image: 459/2868 done
# Added image: 460/2868 done
# Added image: 461/2868 done
# Added image: 462/2868 done
# Added image: 463/2868 done
# Added image: 464/2868 done
# Added image: 465/2868 done
# Added image: 466/2868 done
# Added image: 467/2868 done
# Added image: 468/2868 done
# Added image: 469/2868 done
# Added image: 470/2868 done
# Added image: 471/2868 done
# Added image: 472/2868 done
# Added image: 473/2868 done
# Added image: 474/2868 done
# Added image: 475/2868 done
# Added image: 476/2868 done
# Added image: 477/2868 done
# Added image: 478/2868 done
# Added image: 479/2868 done
# Added image: 480/2868 done
# Added image: 481/2868 done
# Added image: 482/2868 done
# Added image: 483/2868 done
# Added image: 484/2868 done
# Added image: 485/2868 done
# Added image: 486/2868 done
# Added image: 487/2868 done
# Added image: 488/2868 done
# Added image: 489/2868 done
# Added image: 490/2868 done
# Added image: 491/2868 done
# Added image: 492/2868 done
# Added image: 493/2868 done
# Added image: 494/2868 done
# Added image: 495/2868 done
# Added image: 496/2868 done
# Added image: 497/2868 done
# Added image: 498/2868 done
# Added image: 499/2868 done
# Added image: 500/2868 done
# Added image: 501/2868 done
# Added image: 502/2868 done
# Added image: 503/2868 done
# Added image: 504/2868 done
# Added image: 505/2868 done
# Added image: 506/2868 done
# Added image: 507/2868 done
# Added image: 508/2868 done
# Added image: 509/2868 done
# Added image: 510/2868 done
# Added image: 511/2868 done
# Added image: 512/2868 done
# Added image: 513/2868 done
# Added image: 514/2868 done
# Added image: 515/2868 done
# Added image: 516/2868 done
# Added image: 517/2868 done
# Added image: 518/2868 done
# Added image: 519/2868 done
# Added image: 520/2868 done
# Added image: 521/2868 done
# Added image: 522/2868 done
# Added image: 523/2868 done
# Added image: 524/2868 done
# Added image: 525/2868 done
# Added image: 526/2868 done
# Added image: 527/2868 done
# Added image: 528/2868 done
# Added image: 529/2868 done
# Added image: 530/2868 done
# Added image: 531/2868 done
# Added image: 532/2868 done
# Added image: 533/2868 done
# Added image: 534/2868 done
# Added image: 535/2868 done
# Added image: 536/2868 done
# Added image: 537/2868 done
# Added image: 538/2868 done
# Added image: 539/2868 done
# Added image: 540/2868 done
# Added image: 541/2868 done
# Added image: 542/2868 done
# Added image: 543/2868 done
# Added image: 544/2868 done
# Added image: 545/2868 done
# Added image: 546/2868 done
# Added image: 547/2868 done
# Added image: 548/2868 done
# Added image: 549/2868 done
# Added image: 550/2868 done
# Added image: 551/2868 done
# Added image: 552/2868 done
# Added image: 553/2868 done
# Added image: 554/2868 done
# Added image: 555/2868 done
# Added image: 556/2868 done
# Added image: 557/2868 done
# Added image: 558/2868 done
# Added image: 559/2868 done
# Added image: 560/2868 done
# Added image: 561/2868 done
# Added image: 562/2868 done
# Added image: 563/2868 done
# Added image: 564/2868 done
# Added image: 565/2868 done
# Added image: 566/2868 done
# Added image: 567/2868 done
# Added image: 568/2868 done
# Added image: 569/2868 done
# Added image: 570/2868 done
# Added image: 571/2868 done
# Added image: 572/2868 done
# Added image: 573/2868 done
# Added image: 574/2868 done
# Added image: 575/2868 done
# Added image: 576/2868 done
# Added image: 577/2868 done
# Added image: 578/2868 done
# Added image: 579/2868 done
# Added image: 580/2868 done
# Added image: 581/2868 done
# Added image: 582/2868 done
# Added image: 583/2868 done
# Added image: 584/2868 done
# Added image: 585/2868 done
# Added image: 586/2868 done
# Added image: 587/2868 done
# Added image: 588/2868 done
# Added image: 589/2868 done
# Added image: 590/2868 done
# Added image: 591/2868 done
# Added image: 592/2868 done
# Added image: 593/2868 done
# Added image: 594/2868 done
# Added image: 595/2868 done
# Added image: 596/2868 done
# Added image: 597/2868 done
# Added image: 598/2868 done
# Added image: 599/2868 done
# Added image: 600/2868 done
# Added image: 601/2868 done
# Added image: 602/2868 done
# Added image: 603/2868 done
# Added image: 604/2868 done
# Added image: 605/2868 done
# Added image: 606/2868 done
# Added image: 607/2868 done
# Added image: 608/2868 done
# Added image: 609/2868 done
# Added image: 610/2868 done
# Added image: 611/2868 done
# Added image: 612/2868 done
# Added image: 613/2868 done
# Added image: 614/2868 done
# Added image: 615/2868 done
# Added image: 616/2868 done
# Added image: 617/2868 done
# Added image: 618/2868 done
# Added image: 619/2868 done
# Added image: 620/2868 done
# Added image: 621/2868 done
# Added image: 622/2868 done
# Added image: 623/2868 done
# Added image: 624/2868 done
# Added image: 625/2868 done
# Added image: 626/2868 done
# Added image: 627/2868 done
# Added image: 628/2868 done
# Added image: 629/2868 done
# Added image: 630/2868 done
# Added image: 631/2868 done
# Added image: 632/2868 done
# Added image: 633/2868 done
# Added image: 634/2868 done
# Added image: 635/2868 done
# Added image: 636/2868 done
# Added image: 637/2868 done
# Added image: 638/2868 done
# Added image: 639/2868 done
# Added image: 640/2868 done
# Added image: 641/2868 done
# Added image: 642/2868 done
# Added image: 643/2868 done
# Added image: 644/2868 done
# Added image: 645/2868 done
# Added image: 646/2868 done
# Added image: 647/2868 done
# Added image: 648/2868 done
# Added image: 649/2868 done
# Added image: 650/2868 done
# Added image: 651/2868 done
# Added image: 652/2868 done
# Added image: 653/2868 done
# Added image: 654/2868 done
# Added image: 655/2868 done
# Added image: 656/2868 done
# Added image: 657/2868 done
# Added image: 658/2868 done
# Added image: 659/2868 done
# Added image: 660/2868 done
# Added image: 661/2868 done
# Added image: 662/2868 done
# Added image: 663/2868 done
# Added image: 664/2868 done
# Added image: 665/2868 done
# Added image: 666/2868 done
# Added image: 667/2868 done
# Added image: 668/2868 done
# Added image: 669/2868 done
# Added image: 670/2868 done
# Added image: 671/2868 done
# Added image: 672/2868 done
# Added image: 673/2868 done
# Added image: 674/2868 done
# Added image: 675/2868 done
# Added image: 676/2868 done
# Added image: 677/2868 done
# Added image: 678/2868 done
# Added image: 679/2868 done
# Added image: 680/2868 done
# Added image: 681/2868 done
# Added image: 682/2868 done
# Added image: 683/2868 done
# Added image: 684/2868 done
# Added image: 685/2868 done
# Added image: 686/2868 done
# Added image: 687/2868 done
# Added image: 688/2868 done
# Added image: 689/2868 done
# Added image: 690/2868 done
# Added image: 691/2868 done
# Added image: 692/2868 done
# Added image: 693/2868 done
# Added image: 694/2868 done
# Added image: 695/2868 done
# Added image: 696/2868 done
# Added image: 697/2868 done
# Added image: 698/2868 done
# Added image: 699/2868 done
# Added image: 700/2868 done
# Added image: 701/2868 done
# Added image: 702/2868 done
# Added image: 703/2868 done
# Added image: 704/2868 done
# Added image: 705/2868 done
# Added image: 706/2868 done
# Added image: 707/2868 done
# Added image: 708/2868 done
# Added image: 709/2868 done
# Added image: 710/2868 done
# Added image: 711/2868 done
# Added image: 712/2868 done
# Added image: 713/2868 done
# Added image: 714/2868 done
# Added image: 715/2868 done
# Added image: 716/2868 done
# Added image: 717/2868 done
# Added image: 718/2868 done
# Added image: 719/2868 done
# Added image: 720/2868 done
# Added image: 721/2868 done
# Added image: 722/2868 done
# Added image: 723/2868 done
# Added image: 724/2868 done
# Added image: 725/2868 done
# Added image: 726/2868 done
# Added image: 727/2868 done
# Added image: 728/2868 done
# Added image: 729/2868 done
# Added image: 730/2868 done
# Added image: 731/2868 done
# Added image: 732/2868 done
# Added image: 733/2868 done
# Added image: 734/2868 done
# Added image: 735/2868 done
# Added image: 736/2868 done
# Added image: 737/2868 done
# Added image: 738/2868 done
# Added image: 739/2868 done
# Added image: 740/2868 done
# Added image: 741/2868 done
# Added image: 742/2868 done
# Added image: 743/2868 done
# Added image: 744/2868 done
# Added image: 745/2868 done
# Added image: 746/2868 done
# Added image: 747/2868 done
# Added image: 748/2868 done
# Added image: 749/2868 done
# Added image: 750/2868 done
# Added image: 751/2868 done
# Added image: 752/2868 done
# Added image: 753/2868 done
# Added image: 754/2868 done
# Added image: 755/2868 done
# Added image: 756/2868 done
# Added image: 757/2868 done
# Added image: 758/2868 done
# Added image: 759/2868 done
# Added image: 760/2868 done
# Added image: 761/2868 done
# Added image: 762/2868 done
# Added image: 763/2868 done
# Added image: 764/2868 done
# Added image: 765/2868 done
# Added image: 766/2868 done
# Added image: 767/2868 done
# Added image: 768/2868 done
# Added image: 769/2868 done
# Added image: 770/2868 done
# Added image: 771/2868 done
# Added image: 772/2868 done
# Added image: 773/2868 done
# Added image: 774/2868 done
# Added image: 775/2868 done
# Added image: 776/2868 done
# Added image: 777/2868 done
# Added image: 778/2868 done
# Added image: 779/2868 done
# Added image: 780/2868 done
# Added image: 781/2868 done
# Added image: 782/2868 done
# Added image: 783/2868 done
# Added image: 784/2868 done
# Added image: 785/2868 done
# Added image: 786/2868 done
# Added image: 787/2868 done
# Added image: 788/2868 done
# Added image: 789/2868 done
# Added image: 790/2868 done
# Added image: 791/2868 done
# Added image: 792/2868 done
# Added image: 793/2868 done
# Added image: 794/2868 done
# Added image: 795/2868 done
# Added image: 796/2868 done
# Added image: 797/2868 done
# Added image: 798/2868 done
# Added image: 799/2868 done
# Added image: 800/2868 done
# Added image: 801/2868 done
# Added image: 802/2868 done
# Added image: 803/2868 done
# Added image: 804/2868 done
# Added image: 805/2868 done
# Added image: 806/2868 done
# Added image: 807/2868 done
# Added image: 808/2868 done
# Added image: 809/2868 done
# Added image: 810/2868 done
# Added image: 811/2868 done
# Added image: 812/2868 done
# Added image: 813/2868 done
# Added image: 814/2868 done
# Added image: 815/2868 done
# Added image: 816/2868 done
# Added image: 817/2868 done
# Added image: 818/2868 done
# Added image: 819/2868 done
# Added image: 820/2868 done
# Added image: 821/2868 done
# Added image: 822/2868 done
# Added image: 823/2868 done
# Added image: 824/2868 done
# Added image: 825/2868 done
# Added image: 826/2868 done
# Added image: 827/2868 done
# Added image: 828/2868 done
# Added image: 829/2868 done
# Added image: 830/2868 done
# Added image: 831/2868 done
# Added image: 832/2868 done
# Added image: 833/2868 done
# Added image: 834/2868 done
# Added image: 835/2868 done
# Added image: 836/2868 done
# Added image: 837/2868 done
# Added image: 838/2868 done
# Added image: 839/2868 done
# Added image: 840/2868 done
# Added image: 841/2868 done
# Added image: 842/2868 done
# Added image: 843/2868 done
# Added image: 844/2868 done
# Added image: 845/2868 done
# Added image: 846/2868 done
# Added image: 847/2868 done
# Added image: 848/2868 done
# Added image: 849/2868 done
# Added image: 850/2868 done
# Added image: 851/2868 done
# Added image: 852/2868 done
# Added image: 853/2868 done
# Added image: 854/2868 done
# Added image: 855/2868 done
# Added image: 856/2868 done
# Added image: 857/2868 done
# Added image: 858/2868 done
# Added image: 859/2868 done
# Added image: 860/2868 done
# Added image: 861/2868 done
# Added image: 862/2868 done
# Added image: 863/2868 done
# Added image: 864/2868 done
# Added image: 865/2868 done
# Added image: 866/2868 done
# Added image: 867/2868 done
# Added image: 868/2868 done
# Added image: 869/2868 done
# Added image: 870/2868 done
# Added image: 871/2868 done
# Added image: 872/2868 done
# Added image: 873/2868 done
# Added image: 874/2868 done
# Added image: 875/2868 done
# Added image: 876/2868 done
# Added image: 877/2868 done
# Added image: 878/2868 done
# Added image: 879/2868 done
# Added image: 880/2868 done
# Added image: 881/2868 done
# Added image: 882/2868 done
# Added image: 883/2868 done
# Added image: 884/2868 done
# Added image: 885/2868 done
# Added image: 886/2868 done
# Added image: 887/2868 done
# Added image: 888/2868 done
# Added image: 889/2868 done
# Added image: 890/2868 done
# Added image: 891/2868 done
# Added image: 892/2868 done
# Added image: 893/2868 done
# Added image: 894/2868 done
# Added image: 895/2868 done
# Added image: 896/2868 done
# Added image: 897/2868 done
# Added image: 898/2868 done
# Added image: 899/2868 done
# Added image: 900/2868 done
# Added image: 901/2868 done
# Added image: 902/2868 done
# Added image: 903/2868 done
# Added image: 904/2868 done
# Added image: 905/2868 done
# Added image: 906/2868 done
# Added image: 907/2868 done
# Added image: 908/2868 done
# Added image: 909/2868 done
# Added image: 910/2868 done
# Added image: 911/2868 done
# Added image: 912/2868 done
# Added image: 913/2868 done
# Added image: 914/2868 done
# Added image: 915/2868 done
# Added image: 916/2868 done
# Added image: 917/2868 done
# Added image: 918/2868 done
# Added image: 919/2868 done
# Added image: 920/2868 done
# Added image: 921/2868 done
# Added image: 922/2868 done
# Added image: 923/2868 done
# Added image: 924/2868 done
# Added image: 925/2868 done
# Added image: 926/2868 done
# Added image: 927/2868 done
# Added image: 928/2868 done
# Added image: 929/2868 done
# Added image: 930/2868 done
# Added image: 931/2868 done
# Added image: 932/2868 done
# Added image: 933/2868 done
# Added image: 934/2868 done
# Added image: 935/2868 done
# Added image: 936/2868 done
# Added image: 937/2868 done
# Added image: 938/2868 done
# Added image: 939/2868 done
# Added image: 940/2868 done
# Added image: 941/2868 done
# Added image: 942/2868 done
# Added image: 943/2868 done
# Added image: 944/2868 done
# Added image: 945/2868 done
# Added image: 946/2868 done
# Added image: 947/2868 done
# Added image: 948/2868 done
# Added image: 949/2868 done
# Added image: 950/2868 done
# Added image: 951/2868 done
# Added image: 952/2868 done
# Added image: 953/2868 done
# Added image: 954/2868 done
# Added image: 955/2868 done
# Added image: 956/2868 done
# Added image: 957/2868 done
# Added image: 958/2868 done
# Added image: 959/2868 done
# Added image: 960/2868 done
# Added image: 961/2868 done
# Added image: 962/2868 done
# Added image: 963/2868 done
# Added image: 964/2868 done
# Added image: 965/2868 done
# Added image: 966/2868 done
# Added image: 967/2868 done
# Added image: 968/2868 done
# Added image: 969/2868 done
# Added image: 970/2868 done
# Added image: 971/2868 done
# Added image: 972/2868 done
# Added image: 973/2868 done
# Added image: 974/2868 done
# Added image: 975/2868 done
# Added image: 976/2868 done
# Added image: 977/2868 done
# Added image: 978/2868 done
# Added image: 979/2868 done
# Added image: 980/2868 done
# Added image: 981/2868 done
# Added image: 982/2868 done
# Added image: 983/2868 done
# Added image: 984/2868 done
# Added image: 985/2868 done
# Added image: 986/2868 done
# Added image: 987/2868 done
# Added image: 988/2868 done
# Added image: 989/2868 done
# Added image: 990/2868 done
# Added image: 991/2868 done
# Added image: 992/2868 done
# Added image: 993/2868 done
# Added image: 994/2868 done
# Added image: 995/2868 done
# Added image: 996/2868 done
# Added image: 997/2868 done
# Added image: 998/2868 done
# Added image: 999/2868 done
# Added image: 1000/2868 done
# Added image: 1001/2868 done
# Added image: 1002/2868 done
# Added image: 1003/2868 done
# Added image: 1004/2868 done
# Added image: 1005/2868 done
# Added image: 1006/2868 done
# Added image: 1007/2868 done
# Added image: 1008/2868 done
# Added image: 1009/2868 done
# Added image: 1010/2868 done
# Added image: 1011/2868 done
# Added image: 1012/2868 done
# Added image: 1013/2868 done
# Added image: 1014/2868 done
# Added image: 1015/2868 done
# Added image: 1016/2868 done
# Added image: 1017/2868 done
# Added image: 1018/2868 done
# Added image: 1019/2868 done
# Added image: 1020/2868 done
# Added image: 1021/2868 done
# Added image: 1022/2868 done
# Added image: 1023/2868 done
# Added image: 1024/2868 done
# Added image: 1025/2868 done
# Added image: 1026/2868 done
# Added image: 1027/2868 done
# Added image: 1028/2868 done
# Added image: 1029/2868 done
# Added image: 1030/2868 done
# Added image: 1031/2868 done
# Added image: 1032/2868 done
# Added image: 1033/2868 done
# Added image: 1034/2868 done
# Added image: 1035/2868 done
# Added image: 1036/2868 done
# Added image: 1037/2868 done
# Added image: 1038/2868 done
# Added image: 1039/2868 done
# Added image: 1040/2868 done
# Added image: 1041/2868 done
# Added image: 1042/2868 done
# Added image: 1043/2868 done
# Added image: 1044/2868 done
# Added image: 1045/2868 done
# Added image: 1046/2868 done
# Added image: 1047/2868 done
# Added image: 1048/2868 done
# Added image: 1049/2868 done
# Added image: 1050/2868 done
# Added image: 1051/2868 done
# Added image: 1052/2868 done
# Added image: 1053/2868 done
# Added image: 1054/2868 done
# Added image: 1055/2868 done
# Added image: 1056/2868 done
# Added image: 1057/2868 done
# Added image: 1058/2868 done
# Added image: 1059/2868 done
# Added image: 1060/2868 done
# Added image: 1061/2868 done
# Added image: 1062/2868 done
# Added image: 1063/2868 done
# Added image: 1064/2868 done
# Added image: 1065/2868 done
# Added image: 1066/2868 done
# Added image: 1067/2868 done
# Added image: 1068/2868 done
# Added image: 1069/2868 done
# Added image: 1070/2868 done
# Added image: 1071/2868 done
# Added image: 1072/2868 done
# Added image: 1073/2868 done
# Added image: 1074/2868 done
# Added image: 1075/2868 done
# Added image: 1076/2868 done
# Added image: 1077/2868 done
# Added image: 1078/2868 done
# Added image: 1079/2868 done
# Added image: 1080/2868 done
# Added image: 1081/2868 done
# Added image: 1082/2868 done
# Added image: 1083/2868 done
# Added image: 1084/2868 done
# Added image: 1085/2868 done
# Added image: 1086/2868 done
# Added image: 1087/2868 done
# Added image: 1088/2868 done
# Added image: 1089/2868 done
# Added image: 1090/2868 done
# Added image: 1091/2868 done
# Added image: 1092/2868 done
# Added image: 1093/2868 done
# Added image: 1094/2868 done
# Added image: 1095/2868 done
# Added image: 1096/2868 done
# Added image: 1097/2868 done
# Added image: 1098/2868 done
# Added image: 1099/2868 done
# Added image: 1100/2868 done
# Added image: 1101/2868 done
# Added image: 1102/2868 done
# Added image: 1103/2868 done
# Added image: 1104/2868 done
# Added image: 1105/2868 done
# Added image: 1106/2868 done
# Added image: 1107/2868 done
# Added image: 1108/2868 done
# Added image: 1109/2868 done
# Added image: 1110/2868 done
# Added image: 1111/2868 done
# Added image: 1112/2868 done
# Added image: 1113/2868 done
# Added image: 1114/2868 done
# Added image: 1115/2868 done
# Added image: 1116/2868 done
# Added image: 1117/2868 done
# Added image: 1118/2868 done
# Added image: 1119/2868 done
# Added image: 1120/2868 done
# Added image: 1121/2868 done
# Added image: 1122/2868 done
# Added image: 1123/2868 done
# Added image: 1124/2868 done
# Added image: 1125/2868 done
# Added image: 1126/2868 done
# Added image: 1127/2868 done
# Added image: 1128/2868 done
# Added image: 1129/2868 done
# Added image: 1130/2868 done
# Added image: 1131/2868 done
# Added image: 1132/2868 done
# Added image: 1133/2868 done
# Added image: 1134/2868 done
# Added image: 1135/2868 done
# Added image: 1136/2868 done
# Added image: 1137/2868 done
# Added image: 1138/2868 done
# Added image: 1139/2868 done
# Added image: 1140/2868 done
# Added image: 1141/2868 done
# Added image: 1142/2868 done
# Added image: 1143/2868 done
# Added image: 1144/2868 done
# Added image: 1145/2868 done
# Added image: 1146/2868 done
# Added image: 1147/2868 done
# Added image: 1148/2868 done
# Added image: 1149/2868 done
# Added image: 1150/2868 done
# Added image: 1151/2868 done
# Added image: 1152/2868 done
# Added image: 1153/2868 done
# Added image: 1154/2868 done
# Added image: 1155/2868 done
# Added image: 1156/2868 done
# Added image: 1157/2868 done
# Added image: 1158/2868 done
# Added image: 1159/2868 done
# Added image: 1160/2868 done
# Added image: 1161/2868 done
# Added image: 1162/2868 done
# Added image: 1163/2868 done
# Added image: 1164/2868 done
# Added image: 1165/2868 done
# Added image: 1166/2868 done
# Added image: 1167/2868 done
# Added image: 1168/2868 done
# Added image: 1169/2868 done
# Added image: 1170/2868 done
# Added image: 1171/2868 done
# Added image: 1172/2868 done
# Added image: 1173/2868 done
# Added image: 1174/2868 done
# Added image: 1175/2868 done
# Added image: 1176/2868 done
# Added image: 1177/2868 done
# Added image: 1178/2868 done
# Added image: 1179/2868 done
# Added image: 1180/2868 done
# Added image: 1181/2868 done
# Added image: 1182/2868 done
# Added image: 1183/2868 done
# Added image: 1184/2868 done
# Added image: 1185/2868 done
# Added image: 1186/2868 done
# Added image: 1187/2868 done
# Added image: 1188/2868 done
# Added image: 1189/2868 done
# Added image: 1190/2868 done
# Added image: 1191/2868 done
# Added image: 1192/2868 done
# Added image: 1193/2868 done
# Added image: 1194/2868 done
# Added image: 1195/2868 done
# Added image: 1196/2868 done
# Added image: 1197/2868 done
# Added image: 1198/2868 done
# Added image: 1199/2868 done
# Added image: 1200/2868 done
# Added image: 1201/2868 done
# Added image: 1202/2868 done
# Added image: 1203/2868 done
# Added image: 1204/2868 done
# Added image: 1205/2868 done
# Added image: 1206/2868 done
# Added image: 1207/2868 done
# Added image: 1208/2868 done
# Added image: 1209/2868 done
# Added image: 1210/2868 done
# Added image: 1211/2868 done
# Added image: 1212/2868 done
# Added image: 1213/2868 done
# Added image: 1214/2868 done
# Added image: 1215/2868 done
# Added image: 1216/2868 done
# Added image: 1217/2868 done
# Added image: 1218/2868 done
# Added image: 1219/2868 done
# Added image: 1220/2868 done
# Added image: 1221/2868 done
# Added image: 1222/2868 done
# Added image: 1223/2868 done
# Added image: 1224/2868 done
# Added image: 1225/2868 done
# Added image: 1226/2868 done
# Added image: 1227/2868 done
# Added image: 1228/2868 done
# Added image: 1229/2868 done
# Added image: 1230/2868 done
# Added image: 1231/2868 done
# Added image: 1232/2868 done
# Added image: 1233/2868 done
# Added image: 1234/2868 done
# Added image: 1235/2868 done
# Added image: 1236/2868 done
# Added image: 1237/2868 done
# Added image: 1238/2868 done
# Added image: 1239/2868 done
# Added image: 1240/2868 done
# Added image: 1241/2868 done
# Added image: 1242/2868 done
# Added image: 1243/2868 done
# Added image: 1244/2868 done
# Added image: 1245/2868 done
# Added image: 1246/2868 done
# Added image: 1247/2868 done
# Added image: 1248/2868 done
# Added image: 1249/2868 done
# Added image: 1250/2868 done
# Added image: 1251/2868 done
# Added image: 1252/2868 done
# Added image: 1253/2868 done
# Added image: 1254/2868 done
# Added image: 1255/2868 done
# Added image: 1256/2868 done
# Added image: 1257/2868 done
# Added image: 1258/2868 done
# Added image: 1259/2868 done
# Added image: 1260/2868 done
# Added image: 1261/2868 done
# Added image: 1262/2868 done
# Added image: 1263/2868 done
# Added image: 1264/2868 done
# Added image: 1265/2868 done
# Added image: 1266/2868 done
# Added image: 1267/2868 done
# Added image: 1268/2868 done
# Added image: 1269/2868 done
# Added image: 1270/2868 done
# Added image: 1271/2868 done
# Added image: 1272/2868 done
# Added image: 1273/2868 done
# Added image: 1274/2868 done
# Added image: 1275/2868 done
# Added image: 1276/2868 done
# Added image: 1277/2868 done
# Added image: 1278/2868 done
# Added image: 1279/2868 done
# Added image: 1280/2868 done
# Added image: 1281/2868 done
# Added image: 1282/2868 done
# Added image: 1283/2868 done
# Added image: 1284/2868 done
# Added image: 1285/2868 done
# Added image: 1286/2868 done
# Added image: 1287/2868 done
# Added image: 1288/2868 done
# Added image: 1289/2868 done
# Added image: 1290/2868 done
# Added image: 1291/2868 done
# Added image: 1292/2868 done
# Added image: 1293/2868 done
# Added image: 1294/2868 done
# Added image: 1295/2868 done
# Added image: 1296/2868 done
# Added image: 1297/2868 done
# Added image: 1298/2868 done
# Added image: 1299/2868 done
# Added image: 1300/2868 done
# Added image: 1301/2868 done
# Added image: 1302/2868 done
# Added image: 1303/2868 done
# Added image: 1304/2868 done
# Added image: 1305/2868 done
# Added image: 1306/2868 done
# Added image: 1307/2868 done
# Added image: 1308/2868 done
# Added image: 1309/2868 done
# Added image: 1310/2868 done
# Added image: 1311/2868 done
# Added image: 1312/2868 done
# Added image: 1313/2868 done
# Added image: 1314/2868 done
# Added image: 1315/2868 done
# Added image: 1316/2868 done
# Added image: 1317/2868 done
# Added image: 1318/2868 done
# Added image: 1319/2868 done
# Added image: 1320/2868 done
# Added image: 1321/2868 done
# Added image: 1322/2868 done
# Added image: 1323/2868 done
# Added image: 1324/2868 done
# Added image: 1325/2868 done
# Added image: 1326/2868 done
# Added image: 1327/2868 done
# Added image: 1328/2868 done
# Added image: 1329/2868 done
# Added image: 1330/2868 done
# Added image: 1331/2868 done
# Added image: 1332/2868 done
# Added image: 1333/2868 done
# Added image: 1334/2868 done
# Added image: 1335/2868 done
# Added image: 1336/2868 done
# Added image: 1337/2868 done
# Added image: 1338/2868 done
# Added image: 1339/2868 done
# Added image: 1340/2868 done
# Added image: 1341/2868 done
# Added image: 1342/2868 done
# Added image: 1343/2868 done
# Added image: 1344/2868 done
# Added image: 1345/2868 done
# Added image: 1346/2868 done
# Added image: 1347/2868 done
# Added image: 1348/2868 done
# Added image: 1349/2868 done
# Added image: 1350/2868 done
# Added image: 1351/2868 done
# Added image: 1352/2868 done
# Added image: 1353/2868 done
# Added image: 1354/2868 done
# Added image: 1355/2868 done
# Added image: 1356/2868 done
# Added image: 1357/2868 done
# Added image: 1358/2868 done
# Added image: 1359/2868 done
# Added image: 1360/2868 done
# Added image: 1361/2868 done
# Added image: 1362/2868 done
# Added image: 1363/2868 done
# Added image: 1364/2868 done
# Added image: 1365/2868 done
# Added image: 1366/2868 done
# Added image: 1367/2868 done
# Added image: 1368/2868 done
# Added image: 1369/2868 done
# Added image: 1370/2868 done
# Added image: 1371/2868 done
# Added image: 1372/2868 done
# Added image: 1373/2868 done
# Added image: 1374/2868 done
# Added image: 1375/2868 done
# Added image: 1376/2868 done
# Added image: 1377/2868 done
# Added image: 1378/2868 done
# Added image: 1379/2868 done
# Added image: 1380/2868 done
# Added image: 1381/2868 done
# Added image: 1382/2868 done
# Added image: 1383/2868 done
# Added image: 1384/2868 done
# Added image: 1385/2868 done
# Added image: 1386/2868 done
# Added image: 1387/2868 done
# Added image: 1388/2868 done
# Added image: 1389/2868 done
# Added image: 1390/2868 done
# Added image: 1391/2868 done
# Added image: 1392/2868 done
# Added image: 1393/2868 done
# Added image: 1394/2868 done
# Added image: 1395/2868 done
# Added image: 1396/2868 done
# Added image: 1397/2868 done
# Added image: 1398/2868 done
# Added image: 1399/2868 done
# Added image: 1400/2868 done
# Added image: 1401/2868 done
# Added image: 1402/2868 done
# Added image: 1403/2868 done
# Added image: 1404/2868 done
# Added image: 1405/2868 done
# Added image: 1406/2868 done
# Added image: 1407/2868 done
# Added image: 1408/2868 done
# Added image: 1409/2868 done
# Added image: 1410/2868 done
# Added image: 1411/2868 done
# Added image: 1412/2868 done
# Added image: 1413/2868 done
# Added image: 1414/2868 done
# Added image: 1415/2868 done
# Added image: 1416/2868 done
# Added image: 1417/2868 done
# Added image: 1418/2868 done
# Added image: 1419/2868 done
# Added image: 1420/2868 done
# Added image: 1421/2868 done
# Added image: 1422/2868 done
# Added image: 1423/2868 done
# Added image: 1424/2868 done
# Added image: 1425/2868 done
# Added image: 1426/2868 done
# Added image: 1427/2868 done
# Added image: 1428/2868 done
# Added image: 1429/2868 done
# Added image: 1430/2868 done
# Added image: 1431/2868 done
# Added image: 1432/2868 done
# Added image: 1433/2868 done
# Added image: 1434/2868 done
# Added image: 1435/2868 done
# Added image: 1436/2868 done
# Added image: 1437/2868 done
# Added image: 1438/2868 done
# Added image: 1439/2868 done
# Added image: 1440/2868 done
# Added image: 1441/2868 done
# Added image: 1442/2868 done
# Added image: 1443/2868 done
# Added image: 1444/2868 done
# Added image: 1445/2868 done
# Added image: 1446/2868 done
# Added image: 1447/2868 done
# Added image: 1448/2868 done
# Added image: 1449/2868 done
# Added image: 1450/2868 done
# Added image: 1451/2868 done
# Added image: 1452/2868 done
# Added image: 1453/2868 done
# Added image: 1454/2868 done
# Added image: 1455/2868 done
# Added image: 1456/2868 done
# Added image: 1457/2868 done
# Added image: 1458/2868 done
# Added image: 1459/2868 done
# Added image: 1460/2868 done
# Added image: 1461/2868 done
# Added image: 1462/2868 done
# Added image: 1463/2868 done
# Added image: 1464/2868 done
# Added image: 1465/2868 done
# Added image: 1466/2868 done
# Added image: 1467/2868 done
# Added image: 1468/2868 done
# Added image: 1469/2868 done
# Added image: 1470/2868 done
# Added image: 1471/2868 done
# Added image: 1472/2868 done
# Added image: 1473/2868 done
# Added image: 1474/2868 done
# Added image: 1475/2868 done
# Added image: 1476/2868 done
# Added image: 1477/2868 done
# Added image: 1478/2868 done
# Added image: 1479/2868 done
# Added image: 1480/2868 done
# Added image: 1481/2868 done
# Added image: 1482/2868 done
# Added image: 1483/2868 done
# Added image: 1484/2868 done
# Added image: 1485/2868 done
# Added image: 1486/2868 done
# Added image: 1487/2868 done
# Added image: 1488/2868 done
# Added image: 1489/2868 done
# Added image: 1490/2868 done
# Added image: 1491/2868 done
# Added image: 1492/2868 done
# Added image: 1493/2868 done
# Added image: 1494/2868 done
# Added image: 1495/2868 done
# Added image: 1496/2868 done
# Added image: 1497/2868 done
# Added image: 1498/2868 done
# Added image: 1499/2868 done
# Added image: 1500/2868 done
# Added image: 1501/2868 done
# Added image: 1502/2868 done
# Added image: 1503/2868 done
# Added image: 1504/2868 done
# Added image: 1505/2868 done
# Added image: 1506/2868 done
# Added image: 1507/2868 done
# Added image: 1508/2868 done
# Added image: 1509/2868 done
# Added image: 1510/2868 done
# Added image: 1511/2868 done
# Added image: 1512/2868 done
# Added image: 1513/2868 done
# Added image: 1514/2868 done
# Added image: 1515/2868 done
# Added image: 1516/2868 done
# Added image: 1517/2868 done
# Added image: 1518/2868 done
# Added image: 1519/2868 done
# Added image: 1520/2868 done
# Added image: 1521/2868 done
# Added image: 1522/2868 done
# Added image: 1523/2868 done
# Added image: 1524/2868 done
# Added image: 1525/2868 done
# Added image: 1526/2868 done
# Added image: 1527/2868 done
# Added image: 1528/2868 done
# Added image: 1529/2868 done
# Added image: 1530/2868 done
# Added image: 1531/2868 done
# Added image: 1532/2868 done
# Added image: 1533/2868 done
# Added image: 1534/2868 done
# Added image: 1535/2868 done
# Added image: 1536/2868 done
# Added image: 1537/2868 done
# Added image: 1538/2868 done
# Added image: 1539/2868 done
# Added image: 1540/2868 done
# Added image: 1541/2868 done
# Added image: 1542/2868 done
# Added image: 1543/2868 done
# Added image: 1544/2868 done
# Added image: 1545/2868 done
# Added image: 1546/2868 done
# Added image: 1547/2868 done
# Added image: 1548/2868 done
# Added image: 1549/2868 done
# Added image: 1550/2868 done
# Added image: 1551/2868 done
# Added image: 1552/2868 done
# Added image: 1553/2868 done
# Added image: 1554/2868 done
# Added image: 1555/2868 done
# Added image: 1556/2868 done
# Added image: 1557/2868 done
# Added image: 1558/2868 done
# Added image: 1559/2868 done
# Added image: 1560/2868 done
# Added image: 1561/2868 done
# Added image: 1562/2868 done
# Added image: 1563/2868 done
# Added image: 1564/2868 done
# Added image: 1565/2868 done
# Added image: 1566/2868 done
# Added image: 1567/2868 done
# Added image: 1568/2868 done
# Added image: 1569/2868 done
# Added image: 1570/2868 done
# Added image: 1571/2868 done
# Added image: 1572/2868 done
# Added image: 1573/2868 done
# Added image: 1574/2868 done
# Added image: 1575/2868 done
# Added image: 1576/2868 done
# Added image: 1577/2868 done
# Added image: 1578/2868 done
# Added image: 1579/2868 done
# Added image: 1580/2868 done
# Added image: 1581/2868 done
# Added image: 1582/2868 done
# Added image: 1583/2868 done
# Added image: 1584/2868 done
# Added image: 1585/2868 done
# Added image: 1586/2868 done
# Added image: 1587/2868 done
# Added image: 1588/2868 done
# Added image: 1589/2868 done
# Added image: 1590/2868 done
# Added image: 1591/2868 done
# Added image: 1592/2868 done
# Added image: 1593/2868 done
# Added image: 1594/2868 done
# Added image: 1595/2868 done
# Added image: 1596/2868 done
# Added image: 1597/2868 done
# Added image: 1598/2868 done
# Added image: 1599/2868 done
# Added image: 1600/2868 done
# Added image: 1601/2868 done
# Added image: 1602/2868 done
# Added image: 1603/2868 done
# Added image: 1604/2868 done
# Added image: 1605/2868 done
# Added image: 1606/2868 done
# Added image: 1607/2868 done
# Added image: 1608/2868 done
# Added image: 1609/2868 done
# Added image: 1610/2868 done
# Added image: 1611/2868 done
# Added image: 1612/2868 done
# Added image: 1613/2868 done
# Added image: 1614/2868 done
# Added image: 1615/2868 done
# Added image: 1616/2868 done
# Added image: 1617/2868 done
# Added image: 1618/2868 done
# Added image: 1619/2868 done
# Added image: 1620/2868 done
# Added image: 1621/2868 done
# Added image: 1622/2868 done
# Added image: 1623/2868 done
# Added image: 1624/2868 done
# Added image: 1625/2868 done
# Added image: 1626/2868 done
# Added image: 1627/2868 done
# Added image: 1628/2868 done
# Added image: 1629/2868 done
# Added image: 1630/2868 done
# Added image: 1631/2868 done
# Added image: 1632/2868 done
# Added image: 1633/2868 done
# Added image: 1634/2868 done
# Added image: 1635/2868 done
# Added image: 1636/2868 done
# Added image: 1637/2868 done
# Added image: 1638/2868 done
# Added image: 1639/2868 done
# Added image: 1640/2868 done
# Added image: 1641/2868 done
# Added image: 1642/2868 done
# Added image: 1643/2868 done
# Added image: 1644/2868 done
# Added image: 1645/2868 done
# Added image: 1646/2868 done
# Added image: 1647/2868 done
# Added image: 1648/2868 done
# Added image: 1649/2868 done
# Added image: 1650/2868 done
# Added image: 1651/2868 done
# Added image: 1652/2868 done
# Added image: 1653/2868 done
# Added image: 1654/2868 done
# Added image: 1655/2868 done
# Added image: 1656/2868 done
# Added image: 1657/2868 done
# Added image: 1658/2868 done
# Added image: 1659/2868 done
# Added image: 1660/2868 done
# Added image: 1661/2868 done
# Added image: 1662/2868 done
# Added image: 1663/2868 done
# Added image: 1664/2868 done
# Added image: 1665/2868 done
# Added image: 1666/2868 done
# Added image: 1667/2868 done
# Added image: 1668/2868 done
# Added image: 1669/2868 done
# Added image: 1670/2868 done
# Added image: 1671/2868 done
# Added image: 1672/2868 done
# Added image: 1673/2868 done
# Added image: 1674/2868 done
# Added image: 1675/2868 done
# Added image: 1676/2868 done
# Added image: 1677/2868 done
# Added image: 1678/2868 done
# Added image: 1679/2868 done
# Added image: 1680/2868 done
# Added image: 1681/2868 done
# Added image: 1682/2868 done
# Added image: 1683/2868 done
# Added image: 1684/2868 done
# Added image: 1685/2868 done
# Added image: 1686/2868 done
# Added image: 1687/2868 done
# Added image: 1688/2868 done
# Added image: 1689/2868 done
# Added image: 1690/2868 done
# Added image: 1691/2868 done
# Added image: 1692/2868 done
# Added image: 1693/2868 done
# Added image: 1694/2868 done
# Added image: 1695/2868 done
# Added image: 1696/2868 done
# Added image: 1697/2868 done
# Added image: 1698/2868 done
# Added image: 1699/2868 done
# Added image: 1700/2868 done
# Added image: 1701/2868 done
# Added image: 1702/2868 done
# Added image: 1703/2868 done
# Added image: 1704/2868 done
# Added image: 1705/2868 done
# Added image: 1706/2868 done
# Added image: 1707/2868 done
# Added image: 1708/2868 done
# Added image: 1709/2868 done
# Added image: 1710/2868 done
# Added image: 1711/2868 done
# Added image: 1712/2868 done
# Added image: 1713/2868 done
# Added image: 1714/2868 done
# Added image: 1715/2868 done
# Added image: 1716/2868 done
# Added image: 1717/2868 done
# Added image: 1718/2868 done
# Added image: 1719/2868 done
# Added image: 1720/2868 done
# Added image: 1721/2868 done
# Added image: 1722/2868 done
# Added image: 1723/2868 done
# Added image: 1724/2868 done
# Added image: 1725/2868 done
# Added image: 1726/2868 done
# Added image: 1727/2868 done
# Added image: 1728/2868 done
# Added image: 1729/2868 done
# Added image: 1730/2868 done
# Added image: 1731/2868 done
# Added image: 1732/2868 done
# Added image: 1733/2868 done
# Added image: 1734/2868 done
# Added image: 1735/2868 done
# Added image: 1736/2868 done
# Added image: 1737/2868 done
# Added image: 1738/2868 done
# Added image: 1739/2868 done
# Added image: 1740/2868 done
# Added image: 1741/2868 done
# Added image: 1742/2868 done
# Added image: 1743/2868 done
# Added image: 1744/2868 done
# Added image: 1745/2868 done
# Added image: 1746/2868 done
# Added image: 1747/2868 done
# Added image: 1748/2868 done
# Added image: 1749/2868 done
# Added image: 1750/2868 done
# Added image: 1751/2868 done
# Added image: 1752/2868 done
# ...
# Added image: 2297/2868 done
# Added image: 2298/2868 done
# Added image: 2299/2868 done
# Added image: 2300/2868 done
# Added image: 2301/2868 done
# Added image: 2302/2868 done
# Added image: 2303/2868 done
# Added image: 2304/2868 done
# Added image: 2305/2868 done
# Added image: 2306/2868 done
# Added image: 2307/2868 done
# Added image: 2308/2868 done
# Added image: 2309/2868 done
# Added image: 2310/2868 done
# Added image: 2311/2868 done
# Added image: 2312/2868 done
# Added image: 2313/2868 done
# Added image: 2314/2868 done
# Added image: 2315/2868 done
# Added image: 2316/2868 done
# Added image: 2317/2868 done
# Added image: 2318/2868 done
# Added image: 2319/2868 done
# Added image: 2320/2868 done
# Added image: 2321/2868 done
# Added image: 2322/2868 done
# Added image: 2323/2868 done
# Added image: 2324/2868 done
# Added image: 2325/2868 done
# Added image: 2326/2868 done
# Added image: 2327/2868 done
# Added image: 2328/2868 done
# Added image: 2329/2868 done
# Added image: 2330/2868 done
# Added image: 2331/2868 done
# Added image: 2332/2868 done
# Added image: 2333/2868 done
# Added image: 2334/2868 done
# Added image: 2335/2868 done
# Added image: 2336/2868 done
# Added image: 2337/2868 done
# Added image: 2338/2868 done
# Added image: 2339/2868 done
# Added image: 2340/2868 done
# Added image: 2341/2868 done
# Added image: 2342/2868 done
# Added image: 2343/2868 done
# Added image: 2344/2868 done
# Added image: 2345/2868 done
# Added image: 2346/2868 done
# Added image: 2347/2868 done
# Added image: 2348/2868 done
# Added image: 2349/2868 done
# Added image: 2350/2868 done
# Added image: 2351/2868 done
# Added image: 2352/2868 done
# Added image: 2353/2868 done
# Added image: 2354/2868 done
# Added image: 2355/2868 done
# Added image: 2356/2868 done
# Added image: 2357/2868 done
# Added image: 2358/2868 done
# Added image: 2359/2868 done
# Added image: 2360/2868 done
# Added image: 2361/2868 done
# Added image: 2362/2868 done
# Added image: 2363/2868 done
# Added image: 2364/2868 done
# Added image: 2365/2868 done
# Added image: 2366/2868 done
# Added image: 2367/2868 done
# Added image: 2368/2868 done
# Added image: 2369/2868 done
# Added image: 2370/2868 done
# Added image: 2371/2868 done
# Added image: 2372/2868 done
# Added image: 2373/2868 done
# Added image: 2374/2868 done
# Added image: 2375/2868 done
# Added image: 2376/2868 done
# Added image: 2377/2868 done
# Added image: 2378/2868 done
# Added image: 2379/2868 done
# Added image: 2380/2868 done
# Added image: 2381/2868 done
# Added image: 2382/2868 done
# Added image: 2383/2868 done
# Added image: 2384/2868 done
# Added image: 2385/2868 done
# Added image: 2386/2868 done
# Added image: 2387/2868 done
# Added image: 2388/2868 done
# Added image: 2389/2868 done
# Added image: 2390/2868 done
# Added image: 2391/2868 done
# Added image: 2392/2868 done
# Added image: 2393/2868 done
# Added image: 2394/2868 done
# Added image: 2395/2868 done
# Added image: 2396/2868 done
# Added image: 2397/2868 done
# Added image: 2398/2868 done
# Added image: 2399/2868 done
# Added image: 2400/2868 done
# Added image: 2401/2868 done
# Added image: 2402/2868 done
# Added image: 2403/2868 done
# Added image: 2404/2868 done
# Added image: 2405/2868 done
# Added image: 2406/2868 done
# Added image: 2407/2868 done
# Added image: 2408/2868 done
# Added image: 2409/2868 done
# Added image: 2410/2868 done
# Added image: 2411/2868 done
# Added image: 2412/2868 done
# Added image: 2413/2868 done
# Added image: 2414/2868 done
# Added image: 2415/2868 done
# Added image: 2416/2868 done
# Added image: 2417/2868 done
# Added image: 2418/2868 done
# Added image: 2419/2868 done
# Added image: 2420/2868 done
# Added image: 2421/2868 done
# Added image: 2422/2868 done
# Added image: 2423/2868 done
# Added image: 2424/2868 done
# Added image: 2425/2868 done
# Added image: 2426/2868 done
# Added image: 2427/2868 done
# Added image: 2428/2868 done
# Added image: 2429/2868 done
# Added image: 2430/2868 done
# Added image: 2431/2868 done
# Added image: 2432/2868 done
# Added image: 2433/2868 done
# Added image: 2434/2868 done
# Added image: 2435/2868 done
# Added image: 2436/2868 done
# Added image: 2437/2868 done
# Added image: 2438/2868 done
# Added image: 2439/2868 done
# Added image: 2440/2868 done
# Added image: 2441/2868 done
# Added image: 2442/2868 done
# Added image: 2443/2868 done
# Added image: 2444/2868 done
# Added image: 2445/2868 done
# Added image: 2446/2868 done
# Added image: 2447/2868 done
# Added image: 2448/2868 done
# Added image: 2449/2868 done
# Added image: 2450/2868 done
# Added image: 2451/2868 done
# Added image: 2452/2868 done
# Added image: 2453/2868 done
# Added image: 2454/2868 done
# Added image: 2455/2868 done
# Added image: 2456/2868 done
# Added image: 2457/2868 done
# Added image: 2458/2868 done
# Added image: 2459/2868 done
# Added image: 2460/2868 done
# Added image: 2461/2868 done
# Added image: 2462/2868 done
# Added image: 2463/2868 done
# Added image: 2464/2868 done
# Added image: 2465/2868 done
# Added image: 2466/2868 done
# Added image: 2467/2868 done
# Added image: 2468/2868 done
# Added image: 2469/2868 done
# Added image: 2470/2868 done
# Added image: 2471/2868 done
# Added image: 2472/2868 done
# Added image: 2473/2868 done
# Added image: 2474/2868 done
# Added image: 2475/2868 done
# Added image: 2476/2868 done
# Added image: 2477/2868 done
# Added image: 2478/2868 done
# Added image: 2479/2868 done
# Added image: 2480/2868 done
# Added image: 2481/2868 done
# Added image: 2482/2868 done
# Added image: 2483/2868 done
# Added image: 2484/2868 done
# Added image: 2485/2868 done
# Added image: 2486/2868 done
# Added image: 2487/2868 done
# Added image: 2488/2868 done
# Added image: 2489/2868 done
# Added image: 2490/2868 done
# Added image: 2491/2868 done
# Added image: 2492/2868 done
# Added image: 2493/2868 done
# Added image: 2494/2868 done
# Added image: 2495/2868 done
# Added image: 2496/2868 done
# Added image: 2497/2868 done
# Added image: 2498/2868 done
# Added image: 2499/2868 done
# Added image: 2500/2868 done
# Added image: 2501/2868 done
# Added image: 2502/2868 done
# Added image: 2503/2868 done
# Added image: 2504/2868 done
# Added image: 2505/2868 done
# Added image: 2506/2868 done
# Added image: 2507/2868 done
# Added image: 2508/2868 done
# Added image: 2509/2868 done
# Added image: 2510/2868 done
# Added image: 2511/2868 done
# Added image: 2512/2868 done
# Added image: 2513/2868 done
# Added image: 2514/2868 done
# Added image: 2515/2868 done
# Added image: 2516/2868 done
# Added image: 2517/2868 done
# Added image: 2518/2868 done
# Added image: 2519/2868 done
# Added image: 2520/2868 done
# Added image: 2521/2868 done
# Added image: 2522/2868 done
# Added image: 2523/2868 done
# Added image: 2524/2868 done
# Added image: 2525/2868 done
# Added image: 2526/2868 done
# Added image: 2527/2868 done
# Added image: 2528/2868 done
# Added image: 2529/2868 done
# Added image: 2530/2868 done
# Added image: 2531/2868 done
# Added image: 2532/2868 done
# Added image: 2533/2868 done
# Added image: 2534/2868 done
# Added image: 2535/2868 done
# Added image: 2536/2868 done
# Added image: 2537/2868 done
# Added image: 2538/2868 done
# Added image: 2539/2868 done
# Added image: 2540/2868 done
# Added image: 2541/2868 done
# Added image: 2542/2868 done
# Added image: 2543/2868 done
# Added image: 2544/2868 done
# Added image: 2545/2868 done
# Added image: 2546/2868 done
# Added image: 2547/2868 done
# Added image: 2548/2868 done
# Added image: 2549/2868 done
# Added image: 2550/2868 done
# Added image: 2551/2868 done
# Added image: 2552/2868 done
# Added image: 2553/2868 done
# Added image: 2554/2868 done
# Added image: 2555/2868 done
# Added image: 2556/2868 done
# Added image: 2557/2868 done
# Added image: 2558/2868 done
# Added image: 2559/2868 done
# Added image: 2560/2868 done
# Added image: 2561/2868 done
# Added image: 2562/2868 done
# Added image: 2563/2868 done
# Added image: 2564/2868 done
# Added image: 2565/2868 done
# Added image: 2566/2868 done
# Added image: 2567/2868 done
# Added image: 2568/2868 done
# Added image: 2569/2868 done
# Added image: 2570/2868 done
# Added image: 2571/2868 done
# Added image: 2572/2868 done
# Added image: 2573/2868 done
# Added image: 2574/2868 done
# Added image: 2575/2868 done
# Added image: 2576/2868 done
# Added image: 2577/2868 done
# Added image: 2578/2868 done
# Added image: 2579/2868 done
# Added image: 2580/2868 done
# Added image: 2581/2868 done
# Added image: 2582/2868 done
# Added image: 2583/2868 done
# Added image: 2584/2868 done
# Added image: 2585/2868 done
# Added image: 2586/2868 done
# Added image: 2587/2868 done
# Added image: 2588/2868 done
# Added image: 2589/2868 done
# Added image: 2590/2868 done
# Added image: 2591/2868 done
# Added image: 2592/2868 done
# Added image: 2593/2868 done
# Added image: 2594/2868 done
# Added image: 2595/2868 done
# Added image: 2596/2868 done
# Added image: 2597/2868 done
# Added image: 2598/2868 done
# Added image: 2599/2868 done
# Added image: 2600/2868 done
# Added image: 2601/2868 done
# Added image: 2602/2868 done
# Added image: 2603/2868 done
# Added image: 2604/2868 done
# Added image: 2605/2868 done
# Added image: 2606/2868 done
# Added image: 2607/2868 done
# Added image: 2608/2868 done
# Added image: 2609/2868 done
# Added image: 2610/2868 done
# Added image: 2611/2868 done
# Added image: 2612/2868 done
# Added image: 2613/2868 done
# Added image: 2614/2868 done
# Added image: 2615/2868 done
# Added image: 2616/2868 done
# Added image: 2617/2868 done
# Added image: 2618/2868 done
# Added image: 2619/2868 done
# Added image: 2620/2868 done
# Added image: 2621/2868 done
# Added image: 2622/2868 done
# Added image: 2623/2868 done
# Added image: 2624/2868 done
# Added image: 2625/2868 done
# Added image: 2626/2868 done
# Added image: 2627/2868 done
# Added image: 2628/2868 done
# Added image: 2629/2868 done
# Added image: 2630/2868 done
# Added image: 2631/2868 done
# Added image: 2632/2868 done
# Added image: 2633/2868 done
# Added image: 2634/2868 done
# Added image: 2635/2868 done
# Added image: 2636/2868 done
# Added image: 2637/2868 done
# Added image: 2638/2868 done
# Added image: 2639/2868 done
# Added image: 2640/2868 done
# Added image: 2641/2868 done
# Added image: 2642/2868 done
# Added image: 2643/2868 done
# Added image: 2644/2868 done
# Added image: 2645/2868 done
# Added image: 2646/2868 done
# Added image: 2647/2868 done
# Added image: 2648/2868 done
# Added image: 2649/2868 done
# Added image: 2650/2868 done
# Added image: 2651/2868 done
# Added image: 2652/2868 done
# Added image: 2653/2868 done
# Added image: 2654/2868 done
# Added image: 2655/2868 done
# Added image: 2656/2868 done
# Added image: 2657/2868 done
# Added image: 2658/2868 done
# Added image: 2659/2868 done
# Added image: 2660/2868 done
# Added image: 2661/2868 done
# Added image: 2662/2868 done
# Added image: 2663/2868 done
# Added image: 2664/2868 done
# Added image: 2665/2868 done
# Added image: 2666/2868 done
# Added image: 2667/2868 done
# Added image: 2668/2868 done
# Added image: 2669/2868 done
# Added image: 2670/2868 done
# Added image: 2671/2868 done
# Added image: 2672/2868 done
# Added image: 2673/2868 done
# Added image: 2674/2868 done
# Added image: 2675/2868 done
# Added image: 2676/2868 done
# Added image: 2677/2868 done
# Added image: 2678/2868 done
# Added image: 2679/2868 done
# Added image: 2680/2868 done
# Added image: 2681/2868 done
# Added image: 2682/2868 done
# Added image: 2683/2868 done
# Added image: 2684/2868 done
# Added image: 2685/2868 done
# Added image: 2686/2868 done
# Added image: 2687/2868 done
# Added image: 2688/2868 done
# Added image: 2689/2868 done
# Added image: 2690/2868 done
# Added image: 2691/2868 done
# Added image: 2692/2868 done
# Added image: 2693/2868 done
# Added image: 2694/2868 done
# Added image: 2695/2868 done
# Added image: 2696/2868 done
# Added image: 2697/2868 done
# Added image: 2698/2868 done
# Added image: 2699/2868 done
# Added image: 2700/2868 done
# Added image: 2701/2868 done
# Added image: 2702/2868 done
# Added image: 2703/2868 done
# Added image: 2704/2868 done
# Added image: 2705/2868 done
# Added image: 2706/2868 done
# Added image: 2707/2868 done
# Added image: 2708/2868 done
# Added image: 2709/2868 done
# Added image: 2710/2868 done
# Added image: 2711/2868 done
# Added image: 2712/2868 done
# Added image: 2713/2868 done
# Added image: 2714/2868 done
# Added image: 2715/2868 done
# Added image: 2716/2868 done
# Added image: 2717/2868 done
# Added image: 2718/2868 done
# Added image: 2719/2868 done
# Added image: 2720/2868 done
# Added image: 2721/2868 done
# Added image: 2722/2868 done
# Added image: 2723/2868 done
# Added image: 2724/2868 done
# Added image: 2725/2868 done
# Added image: 2726/2868 done
# Added image: 2727/2868 done
# Added image: 2728/2868 done
# Added image: 2729/2868 done
# Added image: 2730/2868 done
# Added image: 2731/2868 done
# Added image: 2732/2868 done
# Added image: 2733/2868 done
# Added image: 2734/2868 done
# Added image: 2735/2868 done
# Added image: 2736/2868 done
# Added image: 2737/2868 done
# Added image: 2738/2868 done
# Added image: 2739/2868 done
# Added image: 2740/2868 done
# Added image: 2741/2868 done
# Added image: 2742/2868 done
# Added image: 2743/2868 done
# Added image: 2744/2868 done
# Added image: 2745/2868 done
# Added image: 2746/2868 done
# Added image: 2747/2868 done
# Added image: 2748/2868 done
# Added image: 2749/2868 done
# Added image: 2750/2868 done
# Added image: 2751/2868 done
# Added image: 2752/2868 done
# Added image: 2753/2868 done
# Added image: 2754/2868 done
# Added image: 2755/2868 done
# Added image: 2756/2868 done
# Added image: 2757/2868 done
# Added image: 2758/2868 done
# Added image: 2759/2868 done
# Added image: 2760/2868 done
# Added image: 2761/2868 done
# Added image: 2762/2868 done
# Added image: 2763/2868 done
# Added image: 2764/2868 done
# Added image: 2765/2868 done
# Added image: 2766/2868 done
# Added image: 2767/2868 done
# Added image: 2768/2868 done
# Added image: 2769/2868 done
# Added image: 2770/2868 done
# Added image: 2771/2868 done
# Added image: 2772/2868 done
# Added image: 2773/2868 done
# Added image: 2774/2868 done
# Added image: 2775/2868 done
# Added image: 2776/2868 done
# Added image: 2777/2868 done
# Added image: 2778/2868 done
# Added image: 2779/2868 done
# Added image: 2780/2868 done
# Added image: 2781/2868 done
# Added image: 2782/2868 done
# Added image: 2783/2868 done
# Added image: 2784/2868 done
# Added image: 2785/2868 done
# Added image: 2786/2868 done
# Added image: 2787/2868 done
# Added image: 2788/2868 done
# Added image: 2789/2868 done
# Added image: 2790/2868 done
# Added image: 2791/2868 done
# Added image: 2792/2868 done
# Added image: 2793/2868 done
# Added image: 2794/2868 done
# Added image: 2795/2868 done
# Added image: 2796/2868 done
# Added image: 2797/2868 done
# Added image: 2798/2868 done
# Added image: 2799/2868 done
# Added image: 2800/2868 done
# Added image: 2801/2868 done
# Added image: 2802/2868 done
# Added image: 2803/2868 done
# Added image: 2804/2868 done
# Added image: 2805/2868 done
# Added image: 2806/2868 done
# Added image: 2807/2868 done
# Added image: 2808/2868 done
# Added image: 2809/2868 done
# Added image: 2810/2868 done
# Added image: 2811/2868 done
# Added image: 2812/2868 done
# Added image: 2813/2868 done
# Added image: 2814/2868 done
# Added image: 2815/2868 done
# Added image: 2816/2868 done
# Added image: 2817/2868 done
# Added image: 2818/2868 done
# Added image: 2819/2868 done
# Added image: 2820/2868 done
# Added image: 2821/2868 done
# Added image: 2822/2868 done
# Added image: 2823/2868 done
# Added image: 2824/2868 done
# Added image: 2825/2868 done
# Added image: 2826/2868 done
# Added image: 2827/2868 done
# Added image: 2828/2868 done
# Added image: 2829/2868 done
# Added image: 2830/2868 done
# Added image: 2831/2868 done
# Added image: 2832/2868 done
# Added image: 2833/2868 done
# Added image: 2834/2868 done
# Added image: 2835/2868 done
# Added image: 2836/2868 done
# Added image: 2837/2868 done
# Added image: 2838/2868 done
# Added image: 2839/2868 done
# Added image: 2840/2868 done
# Added image: 2841/2868 done
# Added image: 2842/2868 done
# Added image: 2843/2868 done
# Added image: 2844/2868 done
# Added image: 2845/2868 done
# Added image: 2846/2868 done
# Added image: 2847/2868 done
# Added image: 2848/2868 done
# Added image: 2849/2868 done
# Added image: 2850/2868 done
# Added image: 2851/2868 done
# Added image: 2852/2868 done
# Added image: 2853/2868 done
# Added image: 2854/2868 done
# Added image: 2855/2868 done
# Added image: 2856/2868 done
# Added image: 2857/2868 done
# Added image: 2858/2868 done
# Added image: 2859/2868 done
# Added image: 2860/2868 done
# Added image: 2861/2868 done
# Added image: 2862/2868 done
# Added image: 2863/2868 done
# Added image: 2864/2868 done
# Added image: 2865/2868 done
# Added image: 2866/2868 done
# Added image: 2867/2868 done

# %%
# Flatten images
data = np.array(images).reshape((num_images, -1))

# Convert labels to a numpy array
labels = np.array(labels)

# %%
import random
from sklearn import datasets, cross_validation, metrics

import tensorflow as tf
import skflow

random.seed(42)

X_train, X_test, y_train, y_test = cross_validation.train_test_split(data, labels,
    test_size=0.2, random_state=42)

# Build 3 layer DNN with 10, 20, 10 units respecitvely.
classifier = skflow.TensorFlowDNNClassifier(hidden_units=[10, 20, 10],
    n_classes=17, steps=200)

# Fit and predict.
classifier.fit(X_train, y_train)
score = metrics.accuracy_score(y_test, classifier.predict(X_test))
print('Accuracy: {0:f}'.format(score))
print(metrics.classification_report(y_test, classifier.predict(X_test)))
# Out:
# Step #1, avg. loss: 36.14418
# Step #21, avg. loss: 258.42651
# Step #41, avg. loss: 3.03869
# Step #61, avg. loss: 2.91731
# Step #81, epoch #1, avg. loss: 2.83185
# Step #101, epoch #1, avg. loss: 2.75281
# Step #121, epoch #1, avg. loss: 2.70317
# Step #141, epoch #1, avg. loss: 2.68648
# Step #161, epoch #2, avg. loss: 2.67895
# Step #181, epoch #2, avg. loss: 2.66457
# Accuracy: 0.139373
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00        19
#           1       0.00      0.00      0.00         8
#           2       0.00      0.00      0.00        49
#           3       0.00      0.00      0.00        31
#           4       0.14      1.00      0.24        80
#           5       0.00      0.00      0.00        70
#           6       0.00      0.00      0.00        15
#           7       0.00      0.00      0.00        18
#           8       0.00      0.00      0.00        51
#           9       0.00      0.00      0.00        44
#          10       0.00      0.00      0.00        50
#          11       0.00      0.00      0.00        22
#          12       0.00      0.00      0.00        53
#          13       0.00      0.00      0.00         2
#          14       0.00      0.00      0.00        20
#          15       0.00      0.00      0.00        14
#          16       0.00      0.00      0.00        28
#
# avg / total       0.02      0.14      0.03       574
# /Users/mbmay/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
